# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import matplotlib
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import datetime
import warnings
warnings.filterwarnings('ignore')

# MAKE SURE ALL OF THESE ARE INSTALLED

# %%
df = pd.read_csv('data/combined_tweets.csv')
users = df["user"].unique()

# %%
def get_engagements(df):
    viz_df = df.loc[df["has_viz"] == True]
    no_viz_df = df.loc[df["has_viz"] == False]
    
    viz_retweets = viz_df["retweets"].sum()
    viz_replies = viz_df["replies"].sum()
    viz_likes = viz_df["likes"].sum()
    viz_quotes = viz_df["quotes"].sum()
    
    no_viz_retweets = no_viz_df["retweets"].sum()
    no_viz_replies = no_viz_df["replies"].sum()
    no_viz_likes = no_viz_df["likes"].sum()
    no_viz_quotes = no_viz_df["quotes"].sum()
    
    viz_engagements = viz_retweets + viz_replies + viz_likes + viz_quotes
    no_viz_engagements = no_viz_retweets + no_viz_replies + no_viz_likes + no_viz_quotes
    
    total_engagements = viz_engagements + no_viz_engagements
    
    non_viz_tweets = len(no_viz_df)
    viz_tweets = len(viz_df)
    
#     print("viz tweets:", viz_tweets)
#     print("non viz tweets:", non_viz_tweets)
    
#     print("visualization tweet engagements: ", viz_engagements)
#     print("no visualization tweet engagements: ", no_viz_engagements)
#     print("total engagements: ", total_engagements)
    
    return viz_engagements, no_viz_engagements

# %%
def get_tweets(df):
    viz_df = df.loc[df["has_viz"] == True]
    no_viz_df = df.loc[df["has_viz"] == False]
    
    non_viz_tweets = len(no_viz_df)
    viz_tweets = len(viz_df)
    
    return viz_tweets, non_viz_tweets

# %%
def show_agg_pies(df):
    all_viz_tweets = df.loc[df["has_viz"] == True]
    no_viz_tweets = df.loc[df["has_viz"] == False]
    
    labels = 'Total Viz Tweets', 'Total Non-Viz Tweets'
    all_viz_tweets = len(all_viz_tweets)
    no_viz_tweets = len(no_viz_tweets)
    
#     all_viz_tweets, non_viz_tweets = len(all_viz_tweets), len(no_viz_tweets)
    sizes = []
    sizes.append(all_viz_tweets)
    sizes.append(no_viz_tweets)
    
    tweet_label = 'Tweets with viz: ' + str(all_viz_tweets)
    no_tweet_label = 'Tweets without viz: ' + str(no_viz_tweets)
    
    legend_labels_1 = tweet_label, no_tweet_label
    
    #----------------------------------------------------------------------------#
    
    # Pie chart, where the slices will be ordered and plotted counter-clockwise:
    labels_eng = 'Viz Engagements', 'Non-Viz Engagements'
    viz_engagements, non_viz_engagements = get_engagements(df)
    sizes_eng = []
    sizes_eng.append(viz_engagements)
    sizes_eng.append(non_viz_engagements)
    
    eng_viz_label = 'Viz engagements: ' + str(viz_engagements)
    eng_noviz_label = 'Non-Viz engagements: ' + str(non_viz_engagements)
    legend_labels_2 = eng_viz_label, eng_noviz_label
    
    
    #----------------------------------------------------------------------------#
    
    fig, (ax1, ax2) = plt.subplots(1, 2)
    
    ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax1.axis('equal')
    ax1.set_title("All tweets distribution")
    ax1.legend(legend_labels_1)
    
    ax2.pie(sizes_eng, labels=labels_eng, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    ax2.set_title("Proportion of Engagements")
    ax2.legend(legend_labels_2)
    
    
    fig.suptitle('Overall engagement statistics')

    plt.tight_layout()
    
    
    #-----------------------------------------------------------------------------#

#     plt.show()

# %%
def show_pies(disp_df, authorname):
    # Pie chart, where the slices will be ordered and plotted counter-clockwise:
    labels = 'Viz Engagements', 'Non-Viz Engagements'
    viz_engagements, non_viz_engagements = get_engagements(disp_df)
    sizes = []
    sizes.append(viz_engagements)
    sizes.append(non_viz_engagements)
    
    viz_label = 'Viz engagements: ' + str(viz_engagements)
    non_viz_label = 'Non-viz engagements: ' + str(non_viz_engagements)
    
    legend_labels_1 = viz_label, non_viz_label
    
    #----------------------------------------------------------------------------#
    
    # Pie chart, where the slices will be ordered and plotted counter-clockwise:
    labels2 = 'Tweets with Viz', 'Tweets without Viz'
    viz_tweets, non_viz_tweets = get_tweets(disp_df)
    sizes_2 = []
    sizes_2.append(viz_tweets)
    sizes_2.append(non_viz_tweets)
    
    tweet_label = 'Tweets with viz: ' + str(viz_tweets)
    no_tweet_label = 'Tweets without viz: ' + str(non_viz_tweets)
    
    legend_labels_2 = tweet_label, no_tweet_label
    
    #-----------------------------------------------------------------------------#
    
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax1.set_title("Proportion of Engagements")
    ax1.axis('equal')
    ax1.legend(legend_labels_1)
    
    ax2.set_title("Tweets with or without visualizations")
    ax2.pie(sizes_2, labels=labels2, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax2.axis('equal')
    ax2.legend(legend_labels_2)
    
#     fig.suptitle('Horiziontal subplots')
    plt.tight_layout()
    
    

#     plt.show()

# %%
def show_bars(df, authors):
    viz_df = df.loc[df["has_viz"] == True]
    no_viz_df = df.loc[df["has_viz"] == False]
    
    viz_retweets = viz_df["retweets"].sum()
    viz_replies = viz_df["replies"].sum()
    viz_likes = viz_df["likes"].sum()
    viz_quotes = viz_df["quotes"].sum()
    
    no_viz_retweets = no_viz_df["retweets"].sum()
    no_viz_replies = no_viz_df["replies"].sum()
    no_viz_likes = no_viz_df["likes"].sum()
    no_viz_quotes = no_viz_df["quotes"].sum()
    
    viz_engagements = [viz_likes, viz_retweets, viz_replies, viz_quotes]
    non_viz_engagements = [no_viz_likes, no_viz_retweets, no_viz_replies, no_viz_quotes]
    
    groups = [[viz_likes, no_viz_likes], 
              [viz_retweets, no_viz_retweets], 
              [viz_replies, no_viz_replies], 
              [viz_quotes, no_viz_quotes]]
    
    labels = ["Likes", "Retweets", "Replies", "Quotes"]
    index_labels = ["With Viz", "Without Viz"]
    
    test_df = pd.DataFrame(groups, index=labels).T
    test_df = test_df.rename(index={0: 'With Viz', 1: 'Without Viz'} )
    
    ax = test_df.plot.bar()
    ax.set_title("Engagements with and without visualizations")
    ax.set_xlabel("Type of Engagement")
    ax.set_ylabel("Number of Engagements")
    

# disp_df = df.loc[df["user"] == "CDCGov"]
# show_bars(disp_df, "CDCGov")

# %%
def gen_time_series(test_df, authors):
    test_df["date"] = test_df["date"].astype("datetime64")
    uq_months = test_df['date'].dt.strftime("%m/%y").unique().tolist()

    viz_engagements_list = []
    non_viz_engagements_list = []

    for month in uq_months:
        month_df = test_df.loc[test_df['date'].dt.strftime("%m/%y") == month]

        viz_df = month_df.loc[month_df["has_viz"] == True]
        no_viz_df = month_df.loc[month_df["has_viz"] == False]

        viz_retweets = viz_df["retweets"].sum()
        viz_replies = viz_df["replies"].sum()
        viz_likes = viz_df["likes"].sum()
        viz_quotes = viz_df["quotes"].sum()

        viz_engagements = viz_retweets + viz_replies + viz_likes + viz_quotes

        no_viz_retweets = no_viz_df["retweets"].sum()
        no_viz_replies = no_viz_df["replies"].sum()
        no_viz_likes = no_viz_df["likes"].sum()
        no_viz_quotes = no_viz_df["quotes"].sum()

        non_viz_engagements = no_viz_retweets + no_viz_replies + no_viz_likes + no_viz_quotes

        viz_engagements_list.append(viz_engagements)
        non_viz_engagements_list.append(non_viz_engagements)

    # print(viz_engagements_list)
    # print(non_viz_engagements_list)
    # print(uq_months)

    ts_df = pd.DataFrame(columns=["Months", "Viz Engagements", "Non-Viz Engagements"])

    ts_df["Months"] = uq_months
    ts_df["Viz Engagements"] = viz_engagements_list
    ts_df["Non-Viz Engagements"] = non_viz_engagements_list

    ts_df = ts_df.set_index(ts_df["Months"])
    ts_df = ts_df.drop(columns=["Months"])

    ts_df_plot = ts_df.plot(label='Engagements', color=['orange', 'green'])
    ts_df_plot.set_title("Engagements over Time")
    ts_df_plot.set_xlabel("Date")
    ts_df_plot.set_ylabel("Engagements")

# %%
show_agg_pies(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-14b3514c6146> in <module>
# ----> 1 show_agg_pies(df)
#
# NameError: name 'df' is not defined

# %%
def f(authors):
    disp_df = df.loc[df["user"] == authors]
    show_pies(disp_df, authors)
    show_bars(disp_df, authors)
    gen_time_series(disp_df, authors)

interact(f, authors=users);
# Out:
# interactive(children=(Dropdown(description='authors', options=('abmakulec', 'aetiology', 'alicesim', 'AmeshAA'…

# %%
# test_df
# Out:
#                  tweet_id    user  \
# 4348  1375898173978382337  CDCGov
# 4349  1375890228574044161  CDCGov
# 4350  1375866473667776513  CDCGov
# 4351  1375550876874514433  CDCGov
# 4352  1375533018287325184  CDCGov
# ...                   ...     ...
# 5237  1514340157641707520  CDCGov
# 5238  1514324546484150277  CDCGov
# 5239  1514013506047299594  CDCGov
# 5240  1513985355657187328  CDCGov
# 5241  1513927441093435394  CDCGov
#
#                                                    text                date  \
# 4348  You may be considered a close contact even if ... 2021-03-27 19:51:02
# 4349  Carol Wong, director of Chinatown Learning Cen... 2021-03-27 19:19:27
# 4350  #WearAMask when you are taking care of someone... 2021-03-27 17:45:04
# 4351  Gathering outdoors is safer, but if you gather... 2021-03-26 20:51:00
# 4352  Johnson &amp; Johnson's Janssen #COVID19 vacci... 2021-03-26 19:40:02
# ...                                                 ...                 ...
# 5237  .@ProjectRefocus_ works with communities to mo... 2022-04-13 20:30:03
# 5238  #Parents and Caregivers: Your children ages 5+... 2022-04-13 19:28:01
# 5239  RT @CDCEnvironment: A study by CDC and #ATSDR ... 2022-04-12 22:52:03
# 5240  Parents: Children with disabilities may need a... 2022-04-12 21:00:11
# 5241  Even if you’ve already had #COVID19, mRNA vacc... 2022-04-12 17:10:04
#
#       retweets  replies  likes  quotes  has_viz
# 4348       112       69    232      11     True
# 4349        49       43    204       7     True
# 4350       215       83    487      14     True
# 4351       284      136    502      23     True
# 4352       102       55    272       8     True
# ...        ...      ...    ...     ...      ...
# 5237        24       37     67       5     True
# 5238        58      101    104      12     True
# 5239        15        0      0       0    False
# 5240        55       39    102       3     True
# 5241       131      128    237       8     True
#
# [894 rows x 9 columns]

# %%
# dates = test_df["date"].tolist()

# %%
# truncated_dates = []

# for date in dates:
#     year = date.year
#     month = date.month
#     day = date.day
    
#     truncated_date = datetime.date(year, month, day)
#     truncated_dates.append(truncated_date)
    
# truncated_dates
# Out:
# [datetime.date(2021, 3, 27),
#  datetime.date(2021, 3, 27),
#  datetime.date(2021, 3, 27),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 26),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 21),
#  datetime.date(2021, 3, 21),
#  datetime.date(2021, 3, 20),
#  datetime.date(2021, 3, 20),
#  datetime.date(2021, 3, 20),
#  datetime.date(2021, 3, 20),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 27),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 24),
#  datetime.date(2021, 4, 24),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 18),
#  datetime.date(2021, 4, 17),
#  datetime.date(2021, 4, 17),
#  datetime.date(2021, 4, 17),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 27),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 26),
#  datetime.date(2021, 5, 25),
#  datetime.date(2021, 5, 25),
#  datetime.date(2021, 5, 25),
#  datetime.date(2021, 5, 25),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 24),
#  datetime.date(2021, 5, 23),
#  datetime.date(2021, 5, 23),
#  datetime.date(2021, 5, 22),
#  datetime.date(2021, 5, 22),
#  datetime.date(2021, 5, 22),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 21),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 19),
#  datetime.date(2021, 5, 19),
#  datetime.date(2021, 5, 19),
#  datetime.date(2021, 5, 19),
#  datetime.date(2021, 5, 19),
#  datetime.date(2021, 5, 19),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 18),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 16),
#  datetime.date(2021, 5, 16),
#  datetime.date(2021, 5, 15),
#  datetime.date(2021, 5, 15),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 6, 26),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 24),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 6, 22),
#  datetime.date(2021, 6, 21),
#  datetime.date(2021, 6, 21),
#  datetime.date(2021, 6, 21),
#  datetime.date(2021, 6, 21),
#  datetime.date(2021, 6, 21),
#  datetime.date(2021, 6, 21),
#  datetime.date(2021, 6, 18),
#  datetime.date(2021, 6, 18),
#  datetime.date(2021, 6, 18),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 16),
#  datetime.date(2021, 6, 15),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 27),
#  datetime.date(2021, 7, 26),
#  datetime.date(2021, 7, 26),
#  datetime.date(2021, 7, 26),
#  datetime.date(2021, 7, 24),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 22),
#  datetime.date(2021, 7, 21),
#  datetime.date(2021, 7, 21),
#  datetime.date(2021, 7, 21),
#  datetime.date(2021, 7, 21),
#  datetime.date(2021, 7, 21),
#  datetime.date(2021, 7, 20),
#  datetime.date(2021, 7, 20),
#  datetime.date(2021, 7, 20),
#  datetime.date(2021, 7, 20),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 15),
#  datetime.date(2021, 7, 14),
#  datetime.date(2021, 7, 14),
#  datetime.date(2021, 7, 14),
#  datetime.date(2021, 7, 14),
#  datetime.date(2021, 7, 14),
#  datetime.date(2021, 7, 14),
#  datetime.date(2021, 7, 13),
#  datetime.date(2021, 7, 13),
#  datetime.date(2021, 7, 13),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 8, 24),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 22),
#  datetime.date(2021, 8, 22),
#  datetime.date(2021, 8, 21),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 17),
#  datetime.date(2021, 8, 17),
#  datetime.date(2021, 8, 17),
#  datetime.date(2021, 8, 17),
#  datetime.date(2021, 8, 17),
#  datetime.date(2021, 8, 17),
#  datetime.date(2021, 8, 16),
#  datetime.date(2021, 8, 16),
#  datetime.date(2021, 9, 27),
#  datetime.date(2021, 9, 27),
#  datetime.date(2021, 9, 25),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 21),
#  datetime.date(2021, 9, 21),
#  datetime.date(2021, 9, 21),
#  datetime.date(2021, 9, 21),
#  datetime.date(2021, 9, 21),
#  datetime.date(2021, 9, 20),
#  datetime.date(2021, 9, 20),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 15),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 23),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 21),
#  datetime.date(2021, 10, 21),
#  datetime.date(2021, 10, 21),
#  datetime.date(2021, 10, 21),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 11, 27),
#  datetime.date(2021, 11, 27),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 23),
#  datetime.date(2021, 11, 23),
#  datetime.date(2021, 11, 23),
#  datetime.date(2021, 11, 23),
#  datetime.date(2021, 11, 22),
#  datetime.date(2021, 11, 22),
#  datetime.date(2021, 11, 22),
#  datetime.date(2021, 11, 22),
#  datetime.date(2021, 11, 21),
#  datetime.date(2021, 11, 21),
#  datetime.date(2021, 11, 21),
#  datetime.date(2021, 11, 20),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 15),
#  datetime.date(2021, 11, 15),
#  datetime.date(2021, 11, 14),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 12),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 20),
#  datetime.date(2021, 12, 20),
#  datetime.date(2021, 12, 20),
#  datetime.date(2021, 12, 20),
#  datetime.date(2021, 12, 19),
#  datetime.date(2021, 12, 18),
#  datetime.date(2021, 12, 18),
#  datetime.date(2021, 12, 18),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 15),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 24),
#  datetime.date(2022, 1, 24),
#  datetime.date(2022, 1, 23),
#  datetime.date(2022, 1, 22),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 20),
#  datetime.date(2022, 1, 20),
#  datetime.date(2022, 1, 20),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 18),
#  datetime.date(2022, 1, 18),
#  datetime.date(2022, 1, 18),
#  datetime.date(2022, 1, 17),
#  datetime.date(2022, 1, 17),
#  datetime.date(2022, 1, 15),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 1, 10),
#  datetime.date(2022, 1, 10),
#  datetime.date(2022, 1, 7),
#  datetime.date(2022, 1, 7),
#  datetime.date(2022, 1, 7),
#  datetime.date(2022, 2, 27),
#  datetime.date(2022, 2, 26),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 2, 21),
#  datetime.date(2022, 2, 21),
#  datetime.date(2022, 2, 20),
#  datetime.date(2022, 2, 19),
#  datetime.date(2022, 2, 19),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 14),
#  datetime.date(2022, 2, 14),
#  datetime.date(2022, 2, 12),
#  datetime.date(2022, 2, 11),
#  datetime.date(2022, 2, 11),
#  datetime.date(2022, 2, 11),
#  datetime.date(2022, 2, 11),
#  datetime.date(2022, 3, 26),
#  datetime.date(2022, 3, 25),
#  datetime.date(2022, 3, 25),
#  datetime.date(2022, 3, 25),
#  datetime.date(2022, 3, 25),
#  datetime.date(2022, 3, 25),
#  datetime.date(2022, 3, 25),
#  datetime.date(2022, 3, 24),
#  datetime.date(2022, 3, 24),
#  datetime.date(2022, 3, 24),
#  datetime.date(2022, 3, 24),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 22),
#  datetime.date(2022, 3, 22),
#  datetime.date(2022, 3, 22),
#  datetime.date(2022, 3, 21),
#  datetime.date(2022, 3, 21),
#  datetime.date(2022, 3, 19),
#  datetime.date(2022, 3, 18),
#  datetime.date(2022, 3, 18),
#  datetime.date(2022, 3, 18),
#  datetime.date(2022, 3, 18),
#  datetime.date(2022, 3, 18),
#  datetime.date(2022, 3, 17),
#  datetime.date(2022, 3, 17),
#  datetime.date(2022, 3, 17),
#  datetime.date(2022, 3, 16),
#  datetime.date(2022, 3, 16),
#  datetime.date(2022, 3, 16),
#  datetime.date(2022, 3, 16),
#  datetime.date(2022, 3, 15),
#  datetime.date(2022, 3, 15),
#  datetime.date(2022, 3, 15),
#  datetime.date(2022, 3, 15),
#  datetime.date(2022, 3, 14),
#  datetime.date(2022, 3, 14),
#  datetime.date(2022, 3, 14),
#  datetime.date(2022, 3, 12),
#  datetime.date(2022, 4, 27),
#  datetime.date(2022, 4, 27),
#  datetime.date(2022, 4, 27),
#  datetime.date(2022, 4, 26),
#  datetime.date(2022, 4, 26),
#  datetime.date(2022, 4, 26),
#  datetime.date(2022, 4, 25),
#  datetime.date(2022, 4, 25),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 4, 20),
#  datetime.date(2022, 4, 20),
#  datetime.date(2022, 4, 20),
#  datetime.date(2022, 4, 20),
#  datetime.date(2022, 4, 19),
#  datetime.date(2022, 4, 19),
#  datetime.date(2022, 4, 18),
#  datetime.date(2022, 4, 18),
#  datetime.date(2022, 4, 18),
#  datetime.date(2022, 4, 16),
#  datetime.date(2022, 4, 15),
#  datetime.date(2022, 4, 15),
#  datetime.date(2022, 4, 15),
#  datetime.date(2022, 4, 14),
#  datetime.date(2022, 4, 14),
#  datetime.date(2022, 4, 14),
#  datetime.date(2022, 4, 13),
#  datetime.date(2022, 4, 13),
#  datetime.date(2022, 4, 13),
#  datetime.date(2022, 4, 13),
#  datetime.date(2022, 4, 12),
#  datetime.date(2022, 4, 12),
#  datetime.date(2022, 4, 12)]

# %%
# test_df["truncated_dates"] = truncated_dates
# test_df["truncated_dates"]
# # test_df.set_index(test_df["truncated_dates"])
# Out:
# <ipython-input-19-0cdd401e8384>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["truncated_dates"] = truncated_dates
# 4348    2021-03-27
# 4349    2021-03-27
# 4350    2021-03-27
# 4351    2021-03-26
# 4352    2021-03-26
#            ...
# 5237    2022-04-13
# 5238    2022-04-13
# 5239    2022-04-12
# 5240    2022-04-12
# 5241    2022-04-12
# Name: truncated_dates, Length: 894, dtype: object

# %%
# test_df = test_df.set_index(test_df["truncated_dates"])

# %%
# np.unique(np.array(truncated_dates))
# Out:
# array([datetime.date(2021, 3, 17), datetime.date(2021, 3, 18),
#        datetime.date(2021, 3, 19), datetime.date(2021, 3, 20),
#        datetime.date(2021, 3, 21), datetime.date(2021, 3, 22),
#        datetime.date(2021, 3, 23), datetime.date(2021, 3, 24),
#        datetime.date(2021, 3, 25), datetime.date(2021, 3, 26),
#        datetime.date(2021, 3, 27), datetime.date(2021, 4, 15),
#        datetime.date(2021, 4, 16), datetime.date(2021, 4, 17),
#        datetime.date(2021, 4, 18), datetime.date(2021, 4, 19),
#        datetime.date(2021, 4, 20), datetime.date(2021, 4, 21),
#        datetime.date(2021, 4, 22), datetime.date(2021, 4, 23),
#        datetime.date(2021, 4, 24), datetime.date(2021, 4, 26),
#        datetime.date(2021, 4, 27), datetime.date(2021, 5, 14),
#        datetime.date(2021, 5, 15), datetime.date(2021, 5, 16),
#        datetime.date(2021, 5, 17), datetime.date(2021, 5, 18),
#        datetime.date(2021, 5, 19), datetime.date(2021, 5, 20),
#        datetime.date(2021, 5, 21), datetime.date(2021, 5, 22),
#        datetime.date(2021, 5, 23), datetime.date(2021, 5, 24),
#        datetime.date(2021, 5, 25), datetime.date(2021, 5, 26),
#        datetime.date(2021, 5, 27), datetime.date(2021, 6, 15),
#        datetime.date(2021, 6, 16), datetime.date(2021, 6, 17),
#        datetime.date(2021, 6, 18), datetime.date(2021, 6, 21),
#        datetime.date(2021, 6, 22), datetime.date(2021, 6, 23),
#        datetime.date(2021, 6, 24), datetime.date(2021, 6, 25),
#        datetime.date(2021, 6, 26), datetime.date(2021, 7, 13),
#        datetime.date(2021, 7, 14), datetime.date(2021, 7, 15),
#        datetime.date(2021, 7, 16), datetime.date(2021, 7, 19),
#        datetime.date(2021, 7, 20), datetime.date(2021, 7, 21),
#        datetime.date(2021, 7, 22), datetime.date(2021, 7, 23),
#        datetime.date(2021, 7, 24), datetime.date(2021, 7, 26),
#        datetime.date(2021, 7, 27), datetime.date(2021, 8, 16),
#        datetime.date(2021, 8, 17), datetime.date(2021, 8, 18),
#        datetime.date(2021, 8, 19), datetime.date(2021, 8, 20),
#        datetime.date(2021, 8, 21), datetime.date(2021, 8, 22),
#        datetime.date(2021, 8, 23), datetime.date(2021, 8, 24),
#        datetime.date(2021, 8, 25), datetime.date(2021, 8, 26),
#        datetime.date(2021, 8, 27), datetime.date(2021, 9, 15),
#        datetime.date(2021, 9, 16), datetime.date(2021, 9, 17),
#        datetime.date(2021, 9, 20), datetime.date(2021, 9, 21),
#        datetime.date(2021, 9, 22), datetime.date(2021, 9, 23),
#        datetime.date(2021, 9, 24), datetime.date(2021, 9, 25),
#        datetime.date(2021, 9, 27), datetime.date(2021, 10, 15),
#        datetime.date(2021, 10, 18), datetime.date(2021, 10, 19),
#        datetime.date(2021, 10, 20), datetime.date(2021, 10, 21),
#        datetime.date(2021, 10, 22), datetime.date(2021, 10, 23),
#        datetime.date(2021, 10, 25), datetime.date(2021, 10, 26),
#        datetime.date(2021, 10, 27), datetime.date(2021, 11, 12),
#        datetime.date(2021, 11, 13), datetime.date(2021, 11, 14),
#        datetime.date(2021, 11, 15), datetime.date(2021, 11, 16),
#        datetime.date(2021, 11, 17), datetime.date(2021, 11, 18),
#        datetime.date(2021, 11, 19), datetime.date(2021, 11, 20),
#        datetime.date(2021, 11, 21), datetime.date(2021, 11, 22),
#        datetime.date(2021, 11, 23), datetime.date(2021, 11, 24),
#        datetime.date(2021, 11, 26), datetime.date(2021, 11, 27),
#        datetime.date(2021, 12, 15), datetime.date(2021, 12, 16),
#        datetime.date(2021, 12, 17), datetime.date(2021, 12, 18),
#        datetime.date(2021, 12, 19), datetime.date(2021, 12, 20),
#        datetime.date(2021, 12, 21), datetime.date(2021, 12, 22),
#        datetime.date(2021, 12, 23), datetime.date(2021, 12, 27),
#        datetime.date(2022, 1, 7), datetime.date(2022, 1, 10),
#        datetime.date(2022, 1, 11), datetime.date(2022, 1, 12),
#        datetime.date(2022, 1, 13), datetime.date(2022, 1, 14),
#        datetime.date(2022, 1, 15), datetime.date(2022, 1, 17),
#        datetime.date(2022, 1, 18), datetime.date(2022, 1, 19),
#        datetime.date(2022, 1, 20), datetime.date(2022, 1, 21),
#        datetime.date(2022, 1, 22), datetime.date(2022, 1, 23),
#        datetime.date(2022, 1, 24), datetime.date(2022, 1, 25),
#        datetime.date(2022, 1, 26), datetime.date(2022, 1, 27),
#        datetime.date(2022, 2, 11), datetime.date(2022, 2, 12),
#        datetime.date(2022, 2, 14), datetime.date(2022, 2, 15),
#        datetime.date(2022, 2, 16), datetime.date(2022, 2, 17),
#        datetime.date(2022, 2, 18), datetime.date(2022, 2, 19),
#        datetime.date(2022, 2, 20), datetime.date(2022, 2, 21),
#        datetime.date(2022, 2, 22), datetime.date(2022, 2, 23),
#        datetime.date(2022, 2, 24), datetime.date(2022, 2, 25),
#        datetime.date(2022, 2, 26), datetime.date(2022, 2, 27),
#        datetime.date(2022, 3, 12), datetime.date(2022, 3, 14),
#        datetime.date(2022, 3, 15), datetime.date(2022, 3, 16),
#        datetime.date(2022, 3, 17), datetime.date(2022, 3, 18),
#        datetime.date(2022, 3, 19), datetime.date(2022, 3, 21),
#        datetime.date(2022, 3, 22), datetime.date(2022, 3, 23),
#        datetime.date(2022, 3, 24), datetime.date(2022, 3, 25),
#        datetime.date(2022, 3, 26), datetime.date(2022, 4, 12),
#        datetime.date(2022, 4, 13), datetime.date(2022, 4, 14),
#        datetime.date(2022, 4, 15), datetime.date(2022, 4, 16),
#        datetime.date(2022, 4, 18), datetime.date(2022, 4, 19),
#        datetime.date(2022, 4, 20), datetime.date(2022, 4, 21),
#        datetime.date(2022, 4, 22), datetime.date(2022, 4, 25),
#        datetime.date(2022, 4, 26), datetime.date(2022, 4, 27)],
#       dtype=object)

# %%
# test_df["dt"],test_df["dt_m"] = test_df["date"].dt.year,test_df["date"].dt.month
# test_df["comb_date"] = test_df.apply(lambda row: str(row["dt"])+"-"+str(row["dt_m"]),axis=1)
# test_df
# Out:
#                             tweet_id    user  \
# truncated_dates
# 2021-03-27       1375898173978382337  CDCGov
# 2021-03-27       1375890228574044161  CDCGov
# 2021-03-27       1375866473667776513  CDCGov
# 2021-03-26       1375550876874514433  CDCGov
# 2021-03-26       1375533018287325184  CDCGov
# ...                              ...     ...
# 2022-04-13       1514340157641707520  CDCGov
# 2022-04-13       1514324546484150277  CDCGov
# 2022-04-12       1514013506047299594  CDCGov
# 2022-04-12       1513985355657187328  CDCGov
# 2022-04-12       1513927441093435394  CDCGov
#
#                                                               text  \
# truncated_dates
# 2021-03-27       You may be considered a close contact even if ...
# 2021-03-27       Carol Wong, director of Chinatown Learning Cen...
# 2021-03-27       #WearAMask when you are taking care of someone...
# 2021-03-26       Gathering outdoors is safer, but if you gather...
# 2021-03-26       Johnson &amp; Johnson's Janssen #COVID19 vacci...
# ...                                                            ...
# 2022-04-13       .@ProjectRefocus_ works with communities to mo...
# 2022-04-13       #Parents and Caregivers: Your children ages 5+...
# 2022-04-12       RT @CDCEnvironment: A study by CDC and #ATSDR ...
# 2022-04-12       Parents: Children with disabilities may need a...
# 2022-04-12       Even if you’ve already had #COVID19, mRNA vacc...
#
#                                date  retweets  replies  likes  quotes  \
# truncated_dates
# 2021-03-27      2021-03-27 19:51:02       112       69    232      11
# 2021-03-27      2021-03-27 19:19:27        49       43    204       7
# 2021-03-27      2021-03-27 17:45:04       215       83    487      14
# 2021-03-26      2021-03-26 20:51:00       284      136    502      23
# 2021-03-26      2021-03-26 19:40:02       102       55    272       8
# ...                             ...       ...      ...    ...     ...
# 2022-04-13      2022-04-13 20:30:03        24       37     67       5
# 2022-04-13      2022-04-13 19:28:01        58      101    104      12
# 2022-04-12      2022-04-12 22:52:03        15        0      0       0
# 2022-04-12      2022-04-12 21:00:11        55       39    102       3
# 2022-04-12      2022-04-12 17:10:04       131      128    237       8
#
#                  has_viz truncated_dates    dt  dt_m comb_date
# truncated_dates
# 2021-03-27          True      2021-03-27  2021     3    2021-3
# 2021-03-27          True      2021-03-27  2021     3    2021-3
# 2021-03-27          True      2021-03-27  2021     3    2021-3
# 2021-03-26          True      2021-03-26  2021     3    2021-3
# 2021-03-26          True      2021-03-26  2021     3    2021-3
# ...                  ...             ...   ...   ...       ...
# 2022-04-13          True      2022-04-13  2022     4    2022-4
# 2022-04-13          True      2022-04-13  2022     4    2022-4
# 2022-04-12         False      2022-04-12  2022     4    2022-4
# 2022-04-12          True      2022-04-12  2022     4    2022-4
# 2022-04-12          True      2022-04-12  2022     4    2022-4
#
# [894 rows x 13 columns]

# %%
# test_df["comb_date"].unique()

# %%
# # Plot

# plt.plot(test_df["likes"], marker='o')

# # Labelling 

# plt.xlabel("date")
# plt.ylabel("Number of Likes")
# plt.title("Pandas Time Series Plot")

# # Display

# plt.show()

# %%
# # Plot scatter

# plt.scatter(test_df.index, test_df["likes"])

# # Labelling 

# plt.xlabel("Date")
# plt.ylabel("Number of Likes")

# # Auto space

# plt.tight_layout()

# # Display


# plt.show()
