# %%
import sys, os
import pandas as pd

# %%
#read csv files and create an new combined dataframe.
files = os.listdir("data")
dfs  = []
for file in files:
    if file =="combined_tweets.csv":
        continue;
    dfs.append(pd.read_csv("data/"+file))

# %%
pd.concat(dfs).to_csv("combined_tweets.csv")
# Out:
#    Unnamed: 0      tweet_id        user  \
# 0           0  1.312029e+18     BNONews
# 0           0  1.323902e+18     BNONews
# 0           0  1.353046e+18     BNONews
# 0           0  1.506774e+18     BNONews
# 0           0  1.365736e+18      CDCGov
# ..        ...           ...         ...
# 22         22  1.515378e+18  DrEricDing
# 23         23  1.515326e+18  DrEricDing
# 24         24  1.515323e+18  DrEricDing
# 25         25  1.515082e+18  DrEricDing
# 26         26  1.515072e+18  DrEricDing
#
#                                                  text                 date  \
# 0   RT @BNODesk: NEW: Trump is experiencing "mild ...  10/02/2020 13:58:25
# 0   Republican David Andahl, who died from COVID-1...  11/04/2020 08:18:13
# 0   RT @BNODesk: Legendary talk show host Larry Ki...  01/23/2021 18:23:12
# 0   RT @BNODesk: Stephen Wilhite, creator of the G...  03/23/2022 23:26:00
# 0   Remember: When using household cleaners and di...  02/27/2021 18:52:02
# ..                                                ...                  ...
# 22  The greatest sin &amp; scandal of the early pa...  04/16/2022 17:12:28
# 23  5) the bulk of which were directly from Covid;...  04/16/2022 13:47:15
# 24  📍15 MILLION DEATHS—the @WHO calculates the glo...  04/16/2022 13:36:15
# 25  RT @asosin: “I would just remind people that i...  04/15/2022 21:39:07
# 26  RT @First10EM: We can literally test for COVID...  04/15/2022 20:56:57
#
#     retweets  replies    likes   quotes has_viz
# 0      276.0      0.0      0.0      0.0   False
# 0    11392.0   2022.0  41170.0  25609.0   False
# 0      106.0      0.0      0.0      0.0    True
# 0     1118.0      0.0      0.0      0.0   False
# 0       62.0     20.0    156.0      5.0    True
# ..       ...      ...      ...      ...     ...
# 22    1310.0    275.0   4613.0     93.0   False
# 23      32.0      6.0    231.0      1.0   False
# 24     742.0     73.0   1496.0     52.0   False
# 25     300.0      0.0      0.0      0.0   False
# 26     398.0      0.0      0.0      0.0   False
#
# [1006 rows x 10 columns]
