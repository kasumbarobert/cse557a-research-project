# %%
import sys, os
import pandas as pd
import numpy as np

# %%
#read csv files and create an new combined dataframe.
files = os.listdir("data")
dfs  = []
for file in files:
    if file =="combined_tweets.csv":
        continue;

    if os.stat("data/"+file).st_size < 10:
        print(file)
        continue
        
    df = pd.read_csv("data/"+file)
    if len(df)==0:
        continue
    dfs.append(df)
pd.concat(dfs)[['tweet_id', 'user', 'text', 'date',
       'retweets', 'replies', 'likes', 'quotes', 'has_viz']].to_csv("data/combined_tweets.csv",index=False)
# Out:
# alicesim_month1.csv
# alicesim_month13.csv
# alicesim_month14.csv
# alicesim_month15.csv
# alicesim_month26.csv
# alicesim_month28.csv
# AndrewJacobsNYT_month1.csv
# AndrewJacobsNYT_month12.csv
# AndrewJacobsNYT_month13.csv
# AndrewJacobsNYT_month14.csv
# AndrewJacobsNYT_month17.csv
# AndrewJacobsNYT_month18.csv
# AndrewJacobsNYT_month20.csv
# AndrewJacobsNYT_month21.csv
# AndrewJacobsNYT_month22.csv
# AndrewJacobsNYT_month23.csv
# AndrewJacobsNYT_month27.csv
# AndrewJacobsNYT_month3.csv
# AndrewJacobsNYT_month5.csv
# AndrewJacobsNYT_month6.csv
# AndrewJacobsNYT_month9.csv
# BillGates_month1.csv
# BillGates_month18.csv
# BillGates_month2.csv
# BillGates_month7.csv
# BNONews_month1.csv
# BNONews_month10.csv
# BNONews_month13.csv
# BNONews_month15.csv
# BNONews_month16.csv
# BNONews_month17.csv
# BNONews_month18.csv
# BNONews_month19.csv
# BNONews_month20.csv
# BNONews_month21.csv
# BNONews_month22.csv
# BNONews_month23.csv
# BNONews_month24.csv
# BNONews_month25.csv
# ...

# %%
tweets = pd.read_csv("data/combined_tweets.csv")
tweets
# Out:
#                   tweet_id       user  \
# 0      1331672421636726791  abmakulec
# 1      1331629580558487552  abmakulec
# 2      1331616851319730180  abmakulec
# 3      1331599424880058369  abmakulec
# 4      1331597345235083264  abmakulec
# ...                    ...        ...
# 16239  1518959820048580609        WHO
# 16240  1518677420483784704        WHO
# 16241  1518606162844913665        WHO
# 16242  1518605191771262978        WHO
# 16243  1518489644161277952        WHO
#
#                                                     text                 date  \
# 0      @AlbertoCairo Clearly my brain operates on a s...  11/25/2020 18:53:41
# 1      @AlbertoCairo The vaccine misinformation being...  11/25/2020 16:03:27
# 2      @sanjaygreddy @FILWD @AlexKale17 @CGDev @RANDC...  11/25/2020 15:12:52
# 3      @FILWD @AlexKale17 @CGDev @RANDCorporation @bm...  11/25/2020 14:03:37
# 4      @FILWD @AlexKale17 @CGDev .@RANDCorporation ma...  11/25/2020 13:55:21
# ...

# %%
remove = ["DNC","BillGates","nytimes"] 
user_counts = pd.DataFrame(tweets["user"].value_counts())
user_counts =user_counts.rename(columns={"user": "num_tweets"})
user_counts = user_counts[user_counts["num_tweets"]>150]
new_tweets = tweets.join(user_counts,how="inner",on="user")
new_tweets
# Out:
#                   tweet_id       user  \
# 0      1331672421636726791  abmakulec
# 1      1331629580558487552  abmakulec
# 2      1331616851319730180  abmakulec
# 3      1331599424880058369  abmakulec
# 4      1331597345235083264  abmakulec
# ...                    ...        ...
# 16239  1518959820048580609        WHO
# 16240  1518677420483784704        WHO
# 16241  1518606162844913665        WHO
# 16242  1518605191771262978        WHO
# 16243  1518489644161277952        WHO
#
#                                                     text                 date  \
# 0      @AlbertoCairo Clearly my brain operates on a s...  11/25/2020 18:53:41
# 1      @AlbertoCairo The vaccine misinformation being...  11/25/2020 16:03:27
# 2      @sanjaygreddy @FILWD @AlexKale17 @CGDev @RANDC...  11/25/2020 15:12:52
# 3      @FILWD @AlexKale17 @CGDev @RANDCorporation @bm...  11/25/2020 14:03:37
# 4      @FILWD @AlexKale17 @CGDev .@RANDCorporation ma...  11/25/2020 13:55:21
# ...

# %%
new_tweets.to_csv("data/combined_tweets_filtered.csv",index=False)
